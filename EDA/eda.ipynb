# %%
import pandas as pd 
import matplotlib as mp
print(pd.__version__)
# Out:
# 1.3.5

# %% [markdown]
# ### Importando os Dataframes

# %%
#dataframe de contratos

df_contracts= pd.read_csv('./dataset/churn_contracts.csv')
df_contracts
# Out:
#       customerID  tenure        Contract PaperlessBilling  \
# 0     7590-VHVEG       1  Month-to-month              Yes
# 1     5575-GNVDE      34        One year               No
# 2     3668-QPYBK       2  Month-to-month              Yes
# 3     7795-CFOCW      45        One year               No
# 4     9237-HQITU       2  Month-to-month              Yes
# ...          ...     ...             ...              ...
# 7038  6840-RESVB      24        One year              Yes
# 7039  2234-XADUH      72        One year              Yes
# 7040  4801-JZAZL      11  Month-to-month              Yes
# 7041  8361-LTMKD       4  Month-to-month              Yes
# 7042  3186-AJIEK      66        Two year              Yes
#
#                   PaymentMethod      MonthlyCharges TotalCharges Churn
# 0              Electronic check  29.850000000000001        29.85    No
# 1                  Mailed check  56.950000000000003       1889.5    No
# ...

# %%
# datframe de clientes

df_customers=pd.read_csv('./dataset/churn_customers.csv')
df_customers
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 0     7590-VHVEG  Female              0     Yes         No
# 1     5575-GNVDE    Male              0      No         No
# 2     3668-QPYBK    Male              0      No         No
# 3     7795-CFOCW    Male              0      No         No
# 4     9237-HQITU  Female              0      No         No
# ...          ...     ...            ...     ...        ...
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No
#
# [7043 rows x 5 columns]

# %%
#dataframe de serviços

df_services=pd.read_csv('./dataset/churn_services.csv')
df_services
# Out:
#       customerID PhoneService     MultipleLines InternetService  \
# 0     7590-VHVEG           No  No phone service             DSL
# 1     5575-GNVDE          Yes                No             DSL
# 2     3668-QPYBK          Yes                No             DSL
# 3     7795-CFOCW           No  No phone service             DSL
# 4     9237-HQITU          Yes                No     Fiber optic
# ...          ...          ...               ...             ...
# 7038  6840-RESVB          Yes               Yes             DSL
# 7039  2234-XADUH          Yes               Yes     Fiber optic
# 7040  4801-JZAZL           No  No phone service             DSL
# 7041  8361-LTMKD          Yes               Yes     Fiber optic
# 7042  3186-AJIEK          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# ...

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
## info dos contratos

df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 440.3+ KB

# %% [markdown]
# ### Tratamento de dados

# %%
df_contracts.TotalCharges=pd.to_numeric(df_contracts.TotalCharges, errors='coerce')

# %%
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# ### Renomeando as colunas

# %%
# renomeando a coluna dos clientes

df_customers.rename(columns={'SeniorCitizen': 'Above65yo'})
# Out:
#       customerID  gender  Above65yo Partner Dependents
# 0     7590-VHVEG  Female          0     Yes         No
# 1     5575-GNVDE    Male          0      No         No
# 2     3668-QPYBK    Male          0      No         No
# 3     7795-CFOCW    Male          0      No         No
# 4     9237-HQITU  Female          0      No         No
# ...          ...     ...        ...     ...        ...
# 7038  6840-RESVB    Male          0     Yes        Yes
# 7039  2234-XADUH  Female          0     Yes        Yes
# 7040  4801-JZAZL  Female          0     Yes        Yes
# 7041  8361-LTMKD    Male          1     Yes         No
# 7042  3186-AJIEK    Male          0      No         No
#
# [7043 rows x 5 columns]

# %%
df_customers.rename(columns={'SeniorCitizen':'Above65yo'}, inplace=True)
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ## Unificando Dataframes

# %%
# contar quantidade de registros por dataframe

len(df_contracts)
# Out:
# 7043

# %%
len(df_customers)
# Out:
# 7043

# %%
len(df_services)
# Out:
# 7043

# %%
df_customers.columns = ['IDCliente','Genero','Acimade60','Parceiro','Dependente']
df_customers.head()
# Out:
#     IDCliente  Genero  Acimade60 Parceiro Dependente
# 0  7590-VHVEG  Female          0      Yes         No
# 1  5575-GNVDE    Male          0       No         No
# 2  3668-QPYBK    Male          0       No         No
# 3  7795-CFOCW    Male          0       No         No
# 4  9237-HQITU  Female          0       No         No

# %%
df_contracts.rename(columns={'customerID':'IDCliente'},inplace=True)
df_contracts.head()
# Out:
#     IDCliente  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod     MonthlyCharges         TotalCharges Churn
# 0           Electronic check 29.850000000000001   29.850000000000001    No
# 1               Mailed check 56.950000000000003 1889.500000000000000    No
# 2               Mailed check 53.850000000000001  108.150000000000006   Yes
# 3  Bank transfer (automatic) 42.299999999999997 1840.750000000000000    No
# 4           Electronic check 70.700000000000003  151.650000000000006   Yes

# %%
df_services.rename(columns={'customerID':'IDCliente'},inplace=True)
df_services.head()
# Out:
#     IDCliente PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No

# %%
df_temp = df_customers.merge(df_services,on=['IDCliente'])

# %%
df_temp
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 1     5575-GNVDE    Male          0       No         No          Yes
# 2     3668-QPYBK    Male          0       No         No          Yes
# 3     7795-CFOCW    Male          0       No         No           No
# 4     9237-HQITU  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7038  6840-RESVB    Male          0      Yes        Yes          Yes
# 7039  2234-XADUH  Female          0      Yes        Yes          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
# 7042  3186-AJIEK    Male          0       No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df_churn_temp=df_temp.merge(df_contracts, left_on='IDCliente',right_on='IDCliente')
df_churn_temp
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 1     5575-GNVDE    Male          0       No         No          Yes
# 2     3668-QPYBK    Male          0       No         No          Yes
# 3     7795-CFOCW    Male          0       No         No           No
# 4     9237-HQITU  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7038  6840-RESVB    Male          0      Yes        Yes          Yes
# 7039  2234-XADUH  Female          0      Yes        Yes          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
# 7042  3186-AJIEK    Male          0       No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
df_churn= df_customers.merge(df_services,on=['IDCliente']).merge(df_contracts,on=['IDCliente'])

# %%
df_churn
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 1     5575-GNVDE    Male          0       No         No          Yes
# 2     3668-QPYBK    Male          0       No         No          Yes
# 3     7795-CFOCW    Male          0       No         No           No
# 4     9237-HQITU  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7038  6840-RESVB    Male          0      Yes        Yes          Yes
# 7039  2234-XADUH  Female          0      Yes        Yes          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
# 7042  3186-AJIEK    Male          0       No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %% [markdown]
# ## Detecção de valores ausentes

# %%
# detectar valores ausentes em todas as colunas

df_churn.isna().sum()
# Out:
# IDCliente            0
# Genero               0
# Acimade60            0
# Parceiro             0
# Dependente           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df_churn[df_churn.isna().any(axis=1)]
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 488   4472-LVYGI  Female          0      Yes        Yes           No
# 753   3115-CZMZD    Male          0       No        Yes          Yes
# 936   5709-LVOEQ  Female          0      Yes        Yes          Yes
# 1082  4367-NUYAO    Male          0      Yes        Yes          Yes
# 1340  1371-DWPAZ  Female          0      Yes        Yes           No
# 3331  7644-OMVMY    Male          0      Yes        Yes          Yes
# 3826  3213-VVOLG    Male          0      Yes        Yes          Yes
# 4380  2520-SGTTA  Female          0      Yes        Yes          Yes
# 5218  2923-ARZLG    Male          0      Yes        Yes          Yes
# 6670  4075-WKNIU  Female          0      Yes        Yes          Yes
# 6754  2775-SEFEE    Male          0       No        Yes          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df_churn.isna().any(axis=0).sum()
# Out:
# 1

# %%
df_churn.drop(columns=['TotalCharges'], axis =1)
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 1     5575-GNVDE    Male          0       No         No          Yes
# 2     3668-QPYBK    Male          0       No         No          Yes
# 3     7795-CFOCW    Male          0       No         No           No
# 4     9237-HQITU  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7038  6840-RESVB    Male          0      Yes        Yes          Yes
# 7039  2234-XADUH  Female          0      Yes        Yes          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
# 7042  3186-AJIEK    Male          0       No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df_churn.dropna(axis=1)
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 1     5575-GNVDE    Male          0       No         No          Yes
# 2     3668-QPYBK    Male          0       No         No          Yes
# 3     7795-CFOCW    Male          0       No         No           No
# 4     9237-HQITU  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7038  6840-RESVB    Male          0      Yes        Yes          Yes
# 7039  2234-XADUH  Female          0      Yes        Yes          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
# 7042  3186-AJIEK    Male          0       No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df_churn.dropna(axis=0)
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 1     5575-GNVDE    Male          0       No         No          Yes
# 2     3668-QPYBK    Male          0       No         No          Yes
# 3     7795-CFOCW    Male          0       No         No           No
# 4     9237-HQITU  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7038  6840-RESVB    Male          0      Yes        Yes          Yes
# 7039  2234-XADUH  Female          0      Yes        Yes          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
# 7042  3186-AJIEK    Male          0       No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
df_churn.dropna(axis=0, how='all')
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 1     5575-GNVDE    Male          0       No         No          Yes
# 2     3668-QPYBK    Male          0       No         No          Yes
# 3     7795-CFOCW    Male          0       No         No           No
# 4     9237-HQITU  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7038  6840-RESVB    Male          0      Yes        Yes          Yes
# 7039  2234-XADUH  Female          0      Yes        Yes          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
# 7042  3186-AJIEK    Male          0       No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
df_churn.fillna(0)
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 1     5575-GNVDE    Male          0       No         No          Yes
# 2     3668-QPYBK    Male          0       No         No          Yes
# 3     7795-CFOCW    Male          0       No         No           No
# 4     9237-HQITU  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7038  6840-RESVB    Male          0      Yes        Yes          Yes
# 7039  2234-XADUH  Female          0      Yes        Yes          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
# 7042  3186-AJIEK    Male          0       No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
df_churn.dropna(axis=0,how='all')
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 1     5575-GNVDE    Male          0       No         No          Yes
# 2     3668-QPYBK    Male          0       No         No          Yes
# 3     7795-CFOCW    Male          0       No         No           No
# 4     9237-HQITU  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7038  6840-RESVB    Male          0      Yes        Yes          Yes
# 7039  2234-XADUH  Female          0      Yes        Yes          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
# 7042  3186-AJIEK    Male          0       No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %% [markdown]
# ### Análise Univariada
# - Faixa etária do cliente tem uma forte associação com o churn
# - Um com cliente com menos de 6 mes de contrato é mais propenso ao churn
# - Cliente com contrato mensal é mais propenso ao churn

# %%
# Contar clientes usando a variável Churn como referência
df_churn.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
# como identificar valores possívei (únicos) no Dataframe

df_churn.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# como é a distrivuição de Clientes (percentualmente falando) que abandonaram eou continuam ativos

df_churn.Churn.value_counts(normalize=True)
# Out:
# No    0.734630129206304
# Yes   0.265369870793696
# Name: Churn, dtype: float64

# %%
ax = df_churn.Churn.value_counts().plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %%
ax = df_churn.Churn.value_counts(normalize=True).plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '0.73463'), Text(0, 0, '0.26537')]

# %%
# Distribuição por contratos
ax = df_churn.Contract.value_counts().plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3875'), Text(0, 0, '1695'), Text(0, 0, '1473')]

# %%
# Distribuição por contratos
ax = df_churn.Contract.value_counts(normalize=True).plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '0.550192'), Text(0, 0, '0.240664'), Text(0, 0, '0.209144')]

# %%
#histograma do tempo de Contrato

df_churn.tenure.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Histograma do Monthly Charges

df_churn.MonthlyCharges.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Medidas de posição - Média Tempo de  Contrato
df_churn.tenure.mean()
# Out:
# 32.37114865824223

# %%
# Medidas de posição - Mediana Tempo de  Contrato

df_churn.tenure.median()
# Out:
# 29.0

# %%
# Medidas de posição - Moda Tempo de  Contrato

df_churn.tenure.mode()
# Out:
# 0    1
# dtype: int64

# %%
# Medidas de posição - Desvio padrão Tempo de  Contrato

df_churn.tenure.std()
# Out:
# 24.55948102309446

# %%
# Medidas de posição - coeficiente de variação Tempo de  Contrato

df_churn.tenure.std() /df_churn.tenure.mean() * 100
# Out:
# 75.86842617906674

# %%
# quantos cliente possuem um mês de contrato

len(df_churn[(df_churn.tenure == 1)])
# Out:
# 613

# %%
# quanto isso representa percentalmente

len(df_churn[(df_churn.tenure == 1)]) / len(df_churn) * 100
# Out:
# 8.70367741019452

# %%
#quantos clientes possuem entre 1 e 6 meses de contrato

len(df_churn[(df_churn.tenure >= 1) & (df_churn.tenure <= 6)])
# Out:
# 1470

# %%
# apresentar a quantidade de clientes por temo de contrato - Agrupamento com sumarização

df_churn.groupby(['tenure']).size().sort_values(ascending=False)
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Length: 73, dtype: int64

# %%
# apresentar a quantidade de clientes por temo de contrato - Agrupamento com sumarização em um plot

df_churn.groupby(['tenure']).size().sort_values().plot.barh(figsize=(15,15))
# Out:
# <AxesSubplot:ylabel='tenure'>

# %% [markdown]
# # Análise bivariada

# %% [markdown]
# ### Análise de correlação
# Analisar a correlação de duas variaveis

# %%
# Hipotese: Clientes com Contrato do Tipo Mensal são mais propensos a cancelar o serviço
# Construir uma tabela de Contigencia entre tipo de contrato e Churn

pd.crosstab(df_churn.Churn, df_churn.Contract, margins= True, normalize= 'index', margins_name='Total')
# Out:
# Contract    Month-to-month          One year          Two year
# Churn
# No       0.429068419018168 0.252609199845381 0.318322381136452
# Yes      0.885500267522739 0.088817549491707 0.025682182985554
# Total    0.550191679681954 0.209143830753940 0.240664489564106

# %%
# Avaliar a correlação entre duas variáveis categoricas (qualitativas)

#executar um teste de hipotese chamado Qui-Quadrado (Chi-Square) DE Pearson
#num teste de hipotes, duas hipoteses são formuladas: 
# a hipotese nula (H0) : as duas variáveis são independentes
# hipotese alternativa (H1): as duas variáveis não são independentes


# O teste serve para confirmar ou rejeitar a hipotese nula
# Quando a probabilidade de observamos oH) é inferior a 0.05 (rejeitamos), rejeitamos a hipotese nula
# recusamos e seguimos com a complementar (H1)

# %%
#Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_contract = pd.crosstab(df_churn.Churn, df_churn.Contract)

# %%
print(df_crosstab_churn_contract)
# Out:
# Contract  Month-to-month  One year  Two year
# Churn
# No                  2220      1307      1647
# Yes                 1655       166        48

# %%
# Calcular os Scores e P-Value

from scipy.stats import chi2_contingency

# %%
chi_scores_churn_contract = chi2_contingency(df_crosstab_churn_contract)

print (chi_scores_churn_contract)
# Out:
# (1184.5965720837926, 5.863038300673391e-258, 2, array([[2846.69175067, 1082.11018032, 1245.198069  ],
#        [1028.30824933,  390.88981968,  449.801931  ]]))

# %%
scores_churn_contract = pd.Series(chi_scores_churn_contract[0])

# %%
pvalues_churn_contract = pd.Series(chi_scores_churn_contract[1])

# %%
# Apresentar numeros com decimais sem notação científica

pd.set_option('display.float_format', lambda x : '%.15f' % x)

# %%
# Criar um DF com os resultados

df_chi_scores_churn_contract = pd.DataFrame({'Qui2': scores_churn_contract, 'P-Value': pvalues_churn_contract})

# %%
# Analisar os scores e p-values
df_chi_scores_churn_contract
# Out:
#                   Qui2           P-Value
# 0 1184.596572083792580 0.000000000000000

# %% [markdown]
# Conforme o teste estatisico (Chi-Square), o P-Value <= 0.05, desta forma rejeitamos a hiótes nula ou seja as variaveis não sçao independentes. Pelo Qui2 alto podemos afirmar que há uma forte correlação

# %%
# Avalia a correlação entre uma variavel qualitativa e uma quantitativa
# Usar o mesmo tese de Chi-Square, mas transofrmar a variavel quantitativa em qualitativa
# Hipotese: Cliente com menos de 6 meses de contrato é mais propenso a cancelar o serviço

# Criar uma coluna nova no Df com base numa condição de outra coluna

# Coluna = TempoMenor6meses

import numpy as np

# %%
# Criar coluna nova

df_churn['TempoMenor6meses'] = np.where(df_churn.tenure < 6, 'Sim', 'Não')

# %%
df_churn.head()
# Out:
#     IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0  7590-VHVEG  Female          0      Yes         No           No
# 1  5575-GNVDE    Male          0       No         No          Yes
# 2  3668-QPYBK    Male          0       No         No          Yes
# 3  7795-CFOCW    Male          0       No         No           No
# 4  9237-HQITU  Female          0       No         No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# 0          No              No      1  Month-to-month               Yes
# ...

# %%
# gerar um DF da Crosstab (sem totais)
df_crosstab_churn_tenure = pd.crosstab(df_churn.Churn, df_churn.TempoMenor6meses)

df_crosstab_churn_tenure.head()
# Out:
# TempoMenor6meses   Não  Sim
# Churn
# No                4547  627
# Yes               1125  744

# %%
# Calcular os Scores e P-Value

chi_scores_churn_tenure = chi2_contingency(df_crosstab_churn_tenure)

print(chi_scores_churn_tenure)
# Out:
# (669.7216158287102, 1.1485390172689518e-147, 1, array([[4166.82209286, 1007.17790714],
#        [1505.17790714,  363.82209286]]))

# %%
scores_churn_tenure = pd.Series(chi_scores_churn_tenure[0])
pvalues_churn_tenure = pd.Series(chi_scores_churn_tenure[1])

# %%
#criar um DF com os resultados

df_chi_scores_churn_tenure = pd.DataFrame({'Qui2': scores_churn_tenure, 'P-Value': pvalues_churn_tenure})

# %%
# analisar os resultados

# %%
df_chi_scores_churn_tenure
# Out:
#                  Qui2           P-Value
# 0 669.721615828710242 0.000000000000000

# %% [markdown]
# Como o  P-Value <= 0.05, rejeitamos a H0, ou seja as variaveis não são independentes. E vale mencionar que com base do Qui2 resultante das análises, a correlação entre Churn e Tempo de Contrato < 6 meses é menos que a correlação entre churn e tipo de contrato

# %%
#Correlação entre duas variáveis Numéricas
# Tenure com TotalCharges
# A intuição é que clientes com mais tempo de contrato maior o valor pago

# Correlaçãpo entre duas variáveis numéricas - Tenure e TotalCharges - Pearson

df_churn.tenure.corr(df_churn.TotalCharges)
# Out:
# 0.825880460933202

# %%
# Correlaçãpo entre duas variáveis numéricas - Tenure e TotalCharges - Spearman

df_churn.tenure.corr(df_churn.TotalCharges, method='spearman')
# Out:
# 0.8891770805365491

# %% [markdown]
# Há uma forte correlação entre Tenure e Total Charhes usando metodos estatisticos de correlação

# %%
#Apresentar o Plot Scatter entre Tenure e TotalCharges
# Gráfico de Dispersão

df_churn.plot.scatter(x='tenure', y='TotalCharges')
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %% [markdown]
# - Desafio 1 : Validar a primeira hipotese  de que a faixa etaria tem uma forte asssociação com o Churn
#
# - Desafio 2 : Validar com Teste de Hipotese se Contrato está mais propenso ao Churn

# %%
df_idade_churn = pd.crosstab(df_churn.Churn, df_churn.Acimade60)

print(df_idade_churn)
# Out:
# Acimade60     0    1
# Churn
# No         4508  666
# Yes        1393  476

# %%
chi_scores_idade_churn = chi2_contingency(df_idade_churn)

print(chi_scores_idade_churn)
# Out:
# (159.42630036838742, 1.510066805092378e-36, 1, array([[4335.05239245,  838.94760755],
#        [1565.94760755,  303.05239245]]))

# %%
scores_churn_idade = pd.Series(chi_scores_idade_churn[0])
p_values_churn_idade = pd.Series(chi_scores_idade_churn[1])
df_chi_scores_churn_idade = pd.DataFrame({'Qui2': scores_churn_idade, 'P-Value': p_values_churn_idade})
print(df_chi_scores_churn_idade)
# Out:
#                  Qui2           P-Value
# 0 159.426300368387416 0.000000000000000

# %% [markdown]
# ### Outliers
#
# #### Pontos fora da curva
#
# #### Identificar e documentar os outliers
# #### Remover caso necessario
# #### Tranformção dos dados
# #### Binnnig
#     Dividir em intervalos

# %% [markdown]
# ### Detecção de Outliers (Valores Atípicos)

# %%
### Detecção de Outliers (Valores Atípicos)

df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Acimade60         7043 non-null   int64
#  3   Parceiro          7043 non-null   object
#  4   Dependente        7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
# ...

# %%
# Remover linhas com valores nulas

df_churn.dropna(axis=0, inplace=True)

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7032 non-null   object
#  1   Genero            7032 non-null   object
#  2   Acimade60         7032 non-null   int64
#  3   Parceiro          7032 non-null   object
#  4   Dependente        7032 non-null   object
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  tenure            7032 non-null   int64
#  15  Contract          7032 non-null   object
# ...

# %%
# Box Plot - Geral

df_churn['TotalCharges'].plot.box()
# Out:
# <AxesSubplot:>

# %%
# Box Plot agrupado por Contract

df_churn.plot.box(by='Contract', y ='TotalCharges')
# Out:
# <AxesSubplot:>

# %%
# Criar um dataframe somente com clientes do tipo Month-to-Month (Mensal)

df_churn_month = df_churn[df_churn.Contract == 'Month-to-month']
df_churn_month
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 0     7590-VHVEG  Female          0      Yes         No           No
# 2     3668-QPYBK    Male          0       No         No          Yes
# 4     9237-HQITU  Female          0       No         No          Yes
# 5     9305-CDSKC  Female          0       No         No          Yes
# 6     1452-KIOVK    Male          0       No        Yes          Yes
# ...          ...     ...        ...      ...        ...          ...
# 7033  9767-FFLEM    Male          0       No         No          Yes
# 7034  0639-TSIQW  Female          0       No         No          Yes
# 7035  8456-QDAVC    Male          0       No         No          Yes
# 7040  4801-JZAZL  Female          0      Yes        Yes           No
# 7041  8361-LTMKD    Male          1      Yes         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
# Histograma - checar visualemtne a distribuição dos valores é normal

df_churn_month.TotalCharges.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Metodo de detecção de Outliers - Tukey
# Metodo de Tukey - IQR (Interquartile Range)
# IQR - Range Interquartil - Diferença entre o 3º e 1º quartil
# IQR = Q3 - Q1

q1_TotalCharges_month = df_churn_month.TotalCharges.quantile(0.25)
q3_TotalCharges_month = df_churn_month.TotalCharges.quantile(0.75)

iqr_TotalCharges_month = q3_TotalCharges_month - q1_TotalCharges_month
iqr_TotalCharges_month
# Out:
# 1906.4

# %%
# limite inferior e superior

limInf_TotalCharges_month = q1_TotalCharges_month - (1.5 * iqr_TotalCharges_month)
limSup_TotalCharges_month = q3_TotalCharges_month + (1.5 * iqr_TotalCharges_month)
limInf_TotalCharges_month, limSup_TotalCharges_month
# Out:
# (-2699.5000000000005, 4926.1)

# %%
# Filtrar os outliers

df_churn_month[(df_churn_month.TotalCharges < limInf_TotalCharges_month) | (df_churn_month.TotalCharges > limSup_TotalCharges_month)]
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 13    0280-XJGEX    Male          0       No         No          Yes
# 61    1215-FIGMP    Male          0       No         No          Yes
# 93    6067-NGCEU  Female          0       No         No          Yes
# 110   0486-HECZI    Male          0      Yes         No          Yes
# 197   6168-YBYNP    Male          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 6897  2363-BJLSL    Male          0       No         No          Yes
# 6952  6394-MFYNG  Female          0       No         No          Yes
# 6965  7789-CRUVC  Female          1      Yes         No          Yes
# 7023  1035-IPQPU  Female          1      Yes         No          Yes
# 7034  0639-TSIQW  Female          0       No         No          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 13             Yes     Fiber optic             No          Yes  ...
# ...

# %%
# ZScore (usado para distribuição normal)
# Indica quantos  desvios padrões um ponto especifio de dados está distante da média
# zscore = (x - media) / desvio padrão

from scipy.stats import zscore

# %%
z = np.abs(zscore(df_churn_month.TotalCharges))
z
# Out:
# 0      0.830035854105835
# 2      0.781512944511796
# 4      0.754555772515107
# 5      0.340066014124648
# 6      0.359519077072167
#               ...
# 7033   0.778346771186232
# 7034   3.418910216654943
# 7035   0.077987048610201
# 7040   0.633837218378213
# 7041   0.658532466747594
# Name: TotalCharges, Length: 3875, dtype: float64

# %%
df_churn_month[z > 3.0]
# Out:
#        IDCliente  Genero  Acimade60 Parceiro Dependente PhoneService  \
# 93    6067-NGCEU  Female          0       No         No          Yes
# 197   6168-YBYNP    Male          0       No         No          Yes
# 339   1343-EHPYB    Male          0      Yes         No          Yes
# 402   0979-PHULV    Male          0      Yes        Yes          Yes
# 445   7752-XUSCI  Female          0       No         No          Yes
# ...          ...     ...        ...      ...        ...          ...
# 6565  1548-FEHVL    Male          0      Yes         No          Yes
# 6587  7426-GSWPO    Male          1       No         No          Yes
# 6713  4989-LIXVT    Male          1       No         No          Yes
# 7023  1035-IPQPU  Female          1      Yes         No          Yes
# 7034  0639-TSIQW  Female          0       No         No          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 93             Yes     Fiber optic            Yes          Yes  ...
# ...

# %% [markdown]
# ### Automatizando EDA

# %%
# Sweetviz 

import sweetviz as sv

sv_churn_report = sv.analyze(df_churn, target_feat='Churn')
# Out:
# [Summarizing dataframe]                      |          | [  0%]   00:00 -> (? left)
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)

# %%
sv_churn_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %%
sv_churn_report.show_html('churn_report.html', open_browser=True, layout='widescreen')
# Out:
# Report churn_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
